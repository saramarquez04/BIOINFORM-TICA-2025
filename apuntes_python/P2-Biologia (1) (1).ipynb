# %% [markdown]
# # PRACTICA 2
#
# ### ¡Con todo lo aprendido con Python, vamos a resolver unos ejercicios de Bioinformática!
#
# #### 1.- Concatena las cadenas ATGCC y TCCG

# %%
cadena1 = "ATGCC"
cadena2 = "TCCG"

# %%
resultado=cadena1+cadena2
print(resultado)
# Out:
# ATGCCTCCG

# %% [markdown]
# #### 2.- ¿Cuál es la longitud de ATGCGAGT?

# %%
dna="ATGCGAGT"

# %%
longuitud=len(dna)
print(longuitud)
# Out:
# 8

# %% [markdown]
# #### 3.- Con la cadena mgXDyTw, ponla en mayúsculas, luego en minúsculas. Extrae su longitud y divide la cadena por la letra "g"

# %%
cadena="mgXDyTw"

# %%
cadena1=cadena.upper()
print(cadena1)
# Out:
# MGXDYTW

# %%
cadena2=cadena.lower()
print(cadena2)
# Out:
# mgxdytw

# %%
longuitud=len(cadena)
print(longuitud)
# Out:
# 7

# %%
cadena3=cadena.split("g")
print(cadena3)
# Out:
# ['m', 'XDyTw']

# %% [markdown]
# #### 4.- Con la secuencia de aminoácidos vlspadktnv, reemplaza la valina con la tirosina. Pista: usa replace()

# %%
aa = "vlspadktnv"

# %%
nueva_secuencia = aa.replace("v", "y")
print(nueva_secuencia)
# Out:
# ylspadktny

# %% [markdown]
# #### 5.- Cuenta las valinas de la secuencia original anterior.

# %%
aa="vlspaktnv"
num_valinas=aa.count("v")
print(num_valinas)
# Out:
# 2

# %% [markdown]
# #### 6.- Con el diccionario siguiente imprime el valor de BisI y saca el valor de EcoRI con pop(). ¿Qué pasa con el diccionario?

# %%
enzR = {
    'EcoRI':r'GAATTC',
    'AvaII':r'GG(A|T)CC',
    'BisI':r'GC[ATGC]GC'
}

# %%
print(enzR["BisI"])
# Out:
# GC[ATGC]GC

# %%
valor_ecori = enzR.pop("EcoRI")
print("Valor eliminado de EcoRI:", valor_ecori)
print("Diccionario actual:", enzR)
# Out:
# Valor eliminado de EcoRI: GAATTC
# Diccionario actual: {'AvaII': 'GG(A|T)CC', 'BisI': 'GC[ATGC]GC'}

# %%
después de usar el valor pop() el valor EcoRI desaparece del diccionario y al usar la función print queda solo el valor de AvaII y BisI en el diccionario

# %% [markdown]
# #### 7.- Con la secuencia y la lista siguiente, escribe un algoritmo que cuente el número de veces que aparece un elemento de la lista en la secuencia. Pista: hacer un diccionario para almacenar los resultados puede ser buena idea

# %%
dna = "AATGATGAACGAC" 
dinucleotides = ['AA','AT','AG','AC', 
                 'TA','TT','TG','TC', 
                 'GA','GT','GG','GC', 
                 'CA','CT','CG','CT']

# %%
dna = "AATGATGAACGAC" 
dinucleotides = ['AA','AT','AG','AC', 
                 'TA','TT','TG','TC', 
                 'GA','GT','GG','GC', 
                 'CA','CT','CG','CT']
conteo={}

for dinuc in dinucleotides:
    conteo[dinuc]=dna.count(dinuc)

print("Conteo de dinucleotidos:")
for k,v in conteo.items():
    print(k,":",v)
# Out:
# Conteo de dinucleotidos:
# AA : 2
# AT : 2
# AG : 0
# AC : 2
# TA : 0
# TT : 0
# TG : 2
# TC : 0
# GA : 3
# GT : 0
# GG : 0
# GC : 0
# CA : 0
# CT : 0
# CG : 1

# %% [markdown]
# ##### ¿Cuántos counts tiene TC?

# %%
print("\nEl dinucleótido'TC' aparece:", conteo ['TC'])
# Out:
# El dinucleótido'TC' aparece: 0

# %% [markdown]
# ##### ¿Puedes imprimir los dinuleótidos que tengan counts igual a 2?

# %%
print("Dinucleótidos con count=2:")
for k, v in conteo.items():
    if v==2:
        print(k,":",v)
# Out:
# Dinucleótidos con count=2:
# AA : 2
# AT : 2
# AC : 2
# TG : 2
