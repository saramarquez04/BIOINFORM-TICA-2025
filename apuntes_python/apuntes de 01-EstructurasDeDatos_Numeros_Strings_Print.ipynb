# %% [markdown]
# ### Variables

# %% [markdown]
# Hay una serie de reglas para nombrar variables:
# 1. No empezar por números
# 2. No se pueden usar símbolos especiales como: '".,<>/?|()!@#$~%¬-+
# 3. Siempre se considera mejor que se usan las variables en minúsculas
# 4. Evitar usar los caracteres 'I', 'O' o 'l'
# 5. Evitar usar palabras con significado especial en Python como list o str

# %% [markdown]
# ### Números

# %% [markdown]
# Python tiene varios tipos de números, principalmente dos: **enteros o integers** (números positivos o negativos, enteros) y **floating points** (números con decimales). También los exponenciales como 4E2.

# %%
# Suma
1+3
# Out:
# 4

# %%
# Resta
2-1
# Out:
# 1

# %%
# Multiplicación
#la multiplicación se hace con el asterisco
2*5
# Out:
# 10

# %%
# Division
#la división se hace con la barra diagonal
3/2
# Out:
# 1.5

# %%
# Floor o división de piso (// trunca el resultado sin redondear y nos da el número entero)
#trunca el resultado y solo nos sale el número entero (cuando no queremos decimales)
3//2
# Out:
# 1

# %%
# Módulo (nos da el resto)
3%2
# Out:
# 1

# %%
# Potencia
#potencia se pone con dos asteriscos
2**3
# Out:
# 8

# %%
# Raíces (como la potencia al revés)
#importante poner paréntesis para indicar el orden de aparición
# 1º multiplicación y división, luego sumas y restas ...
4**0.5
# Out:
# 2.0

# %%
4**(1/2)
# Out:
# 2.0

# %%
# Orden de operaciones en Python
1+10*10+5

# %%
(1+10)*(10+5)

# %%
# Asignamos números a variables
a=5

# %%
a
# Out:
# 5

# %%
a=5

# %%
a
# Out:
# 5

# %%
a=a+a

# %%
a
# Out:
# 40

# %%
# Reasignamos
a=20

# %%
a
# Out:
# 20

# %%
a=a+a

# %%
a
# Out:
# 40

# %%
mi_valor=100
ratio=0.1
mi_precio=mi_valor*ratio
mi_precio
# Out:
# 10.0

# %%
#Podemos determinar el tipo de una variable con type()
# cuando pones type (tu variable) te sale que tipo de función tienes
# por ejemplo en este caso si ponemos type(mi_valor) y nos da como resultado int significa que nuestro resultado es un número entero (en este caso 10)
#si pusieramos type (mi_precio) y nos da como resultado "float" esque el resultado es un decimal
type(mi_valor)
# Out:
# int

# %% [markdown]
# ### STRINGS

# %% [markdown]
# Guardan piezas de texto, secuencias, etc. Son secuencias de caracteres. Se emplean comillas.

# %% [markdown]
# Son inmutables, una vez creada los elementos ya no se pueden modificar o cambiar. Sí que se pueden concatenar strings.

# %% [markdown]
# Hay funciones útiles como **upper(), lower() o split()**

# %% [markdown]
# Las strings se pueden mostrar con **print(), format() o f-strings()**

# %%
'hello'
# Out:
# 'hello'

# %%
'Esto también es una string'
# Out:
# 'Esto también es una string'

# %%
" esto también me lo lee como una string"
# Out:
# ' esto también me lo lee como una string'

# %%
"y esto también"
# Out:
# 'y esto también'

# %%
# Para algunas cosas la comilla simple no nos serviría
'i'm using this' (no lo reconoce por el apostrofe debido al ingles y da error)
# Out:
#   Cell In[6], line 2
#     'i'm using this'
#                    ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
"i'm using this"
# Out:
# "i'm using this"

# %%
# Print() nos permite mostrar strings en el código
print('Hello World 1')
print('Hello World 2')
print('Use \t to print a new line') (tabulador)
print("\n") (salto de linea)
print('See what I mean?')
# Out:
# Hello World 1
# Hello World 2
# Use 	 to print a new line
#
#
# See what I mean?

# %%
# Podemos usar len() para chequear la longitud de una string
# cuidado porque si pones un espacio se cuenta como longuitud
len("Hello World")
# Out:
# 11

# %%
s= "Hello World" #(sale con comillas)
s
# Out:
# 'Hello World'

# %%
print(s) (sale sin comillas)
# Out:
# Hello World

# %%
s
# Out:
# 'Hello World'

# %%
a=len(s) #(guardas la longuitud del string como la variable a)
print(a) 
type(s) #(le preguntas que tipo de variable es s)
# Out:
# 11
# str

# %%
# En Python se empieza a contar desde el 0
# este comando te devuelve la letra en 1º posición, en nuestro caso la H
s[0]
# Out:
# 'H'

# %%
s="Hello world"

# %%
s
# Out:
# 'Hello world'

# %%
s[0]
# Out:
# 'H'

# %%
s[2]
#este comando te muestra la letra en segunda posición, ojo que la primera posición es la 0
# Out:
# 'l'

# %%
# Coger todo desde el caracter 1 hasta el final
s[3:]
# Out:
# 'lo world'

# %%
# Coger todo desde el principio hasta el número 3 (no incluido)
# este comando muestra desde el principio hasta la posición donde quieres que acabe, en este caso el número 3
s[:3]
# Out:
# 'Hel'

# %%
# Coger todo
s[:]
# Out:
# 'Hello World'

# %%
s
# Out:
# 'Hello World'

# %%
# Podemos coger todo menos la última
s[:-1]
# Out:
# 'Hello Worl'

# %%
s[1:3]
# este comando indica de la posición 1 a la posición 3
# Out:
# 'el'

# %%
s[9:]
# este comando indica de la posición 9 hasta el final de la oración
# Out:
# 'ld'

# %%
# Coger todo pero yendo en pasos de 2
s[::3]
# Out:
# 'HlWl'

# %%
# La mostramos al revés
s[::-1]
# Out:
# 'dlroW olleH'

# %%
s[::-2]
# se muestra la frase al revés y comiendose carácteres de dos en dos
# Out:
# 'drWolH'

# %%
s[0]='x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 s[0]='x'
#
# TypeError: 'str' object does not support item assignment

# %%
# Concatenar
s =s + ' concatename'

# %%
s
# Out:
# 'Hello World concatename concatename concatename'

# %%
# si que podemos usar el multiplicador para crear repetición de elementos
letter='z'
letter*10
# Out:
# 'zzzzzzzzzz'

# %%
# Todo en mayúsculas (no cambia el original)
S=s.upper()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Todo en mayúsculas (no cambia el original)
# ----> 2 S=s.upper()
#
# NameError: name 's' is not defined

# %%
S
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 S
#
# NameError: name 'S' is not defined

# %%
# Todo en minúsculas
S.lower()
# Out:
# 'hello world concatename concatename concatename'

# %%
# Separa la string por los espacios en blanco
s.split()
# Out:
# ['Hello', 'World', 'concatename', 'concatename', 'concatename']

# %%
s.split("l")
# Out:
# ['He', '', 'o Wor', 'd concatename concatename concatename']

# %%
s.split('o')
# Out:
# ['Hell', ' W', 'rld c', 'ncatename c', 'ncatename c', 'ncatename']

# %%
# Tips para hacer un print bonito con las f-strings
nombre='Juan'
print(f"Él dijo que su nombre era {nombre}.")
# Out:
# Él dijo que su nombre era Juan.

# %%
print(f"El dijo que su nombre era {s}.")
# Out:
# El dijo que su nombre era Hello World concatename concatename concatename.

# %%
# Podemos meter la string literal con !r
print(f"Él dijo que su nombre era {nombre!r}.")
# Out:
# Él dijo que su nombre era 'Juan'.

# %%
nombre
# Out:
# 'Juan'

# %%
print(nombre)
# Out:
# Juan
