# %% [markdown]
# # PRACTICA 3
#
#
# ## JUEGO DE ADIVINANZAS
#
# #### Escribe un programa que coja un número entero del 1 al 100, y los jugadores tienen que tratar de adivinar el número.
#
# #### Las reglas son las siguientes:
#
# 1. Si un jugador escoje un número menor que 1 o mayor que 100, el programa dice "FUERA DE LÍMITES"
# 2. En el primer turno del jugador, si está en un rango de 10 del número dice "¡CALIENTE!". Si está fuera de ese rango dice "¡FRIO!"
# 3. En todas las rondas siguientes, si el jugador se acerca más que la vez anterior, dice "¡MAS CALIENTE!". Si está más lejos que la anterior vez dice "¡MAS FRIO!"
# 4. Cuando el jugador acierte el número, les dirá que han acertado y cuántos intentos les ha llevado

# %% [markdown]
# ##### PISTAS
# 1. Trata obtener un número aleatorio entre el 1 y el 100
# 2. Haz una introducción de tu juego y explica las reglas
# 3. Crea una lista que almacene los intentos.
# 4. Haz un bucle que evalúe un número. Prueba que funcione primero. While podría ir bien
# 5. Modifica ese bucle para que compare nuestro número con el intento. Si se acierta usa break, si no puedes usar continue y tienes que seguir preguntando al jugador por nuevos intentos

# %%
import random

#(ponemos las reglas del juego)
print("¡Bienvenido al juego de Adivina el Número!")
print("He escogido un número entre 1 y 100.")
print("Tienes que adivinarlo siguiendo estas reglas:")
print("- Si eliges un número menor que 1 o mayor que 100, te diré 'FUERA DE LÍMITES'.")
print("- En tu primer intento, si estás dentro de 10 del número correcto, te diré '¡CALIENTE!'.")
print("  Si estás más lejos, te diré '¡FRIO!'.")
print("- En los siguientes intentos, te diré '¡MAS CALIENTE!' si te acercas al número, o '¡MAS FRIO!' si te alejas.")
print("- Cuando aciertes, te diré cuántos intentos te ha llevado.")

#(hacemos que el programa elija un número aleatorio del 1 al 100)
numero_secreto = random.randint(1, 100)

#(creamos una lista que almacene los intentos que hace el jugador)
intentos = []

while True:
    try:
     
        intento = int(input("Introduce un número entre 1 y 100: "))
    except ValueError:
        print("Por favor, introduce un número válido.")
        continue

#(nos aseguramos de que el intento del jugador esté dentro de los límites del juego)
    if intento < 1 or intento > 100:
        print("¡FUERA DE LÍMITES!")
        continue

   
    intentos.append(intento)

  
    if len(intentos) == 1:
        if abs(intento - numero_secreto) <= 10:
            print("¡CALIENTE!")
        else:
            print("¡FRIO!")
    else:
        
        if abs(intento - numero_secreto) < abs(intentos[-2] - numero_secreto):
            print("¡MAS CALIENTE!")
        elif abs(intento - numero_secreto) > abs(intentos[-2] - numero_secreto):
            print("¡MAS FRIO!")
        else:
            print("¡Igual que antes!")

#(hacemos que el programa le diga al jugador si ha acertado el número)
    if intento == numero_secreto:
        print(f"¡FELICIDADES! Has adivinado el número {numero_secreto} en {len(intentos)} intentos.")
        break
# Out:
# ¡Bienvenido al juego de Adivina el Número!
# He escogido un número entre 1 y 100.
# Tienes que adivinarlo siguiendo estas reglas:
# - Si eliges un número menor que 1 o mayor que 100, te diré 'FUERA DE LÍMITES'.
# - En tu primer intento, si estás dentro de 10 del número correcto, te diré '¡CALIENTE!'.
#   Si estás más lejos, te diré '¡FRIO!'.
# - En los siguientes intentos, te diré '¡MAS CALIENTE!' si te acercas al número, o '¡MAS FRIO!' si te alejas.
# - Cuando aciertes, te diré cuántos intentos te ha llevado.
